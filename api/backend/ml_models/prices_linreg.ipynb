# %%
import pandas as pd
import requests
import json
import plotly.express as px
import seaborn as sns

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Import and clean the country prices dataset

# %%
prices_df = pd.read_csv(r'C:/Users/npste/Farmers-Market/datasets/apri_ap_crpouta$defaultview_linear.csv')
prices_df = prices_df.drop(['DATAFLOW','LAST UPDATE','freq','OBS_FLAG','CONF_STATUS'],axis=1)
prices_df.drop(prices_df[prices_df['currency'] == 'National currency'].index, inplace=True)

# %% [markdown]
# ### Note: Half the data for Luxembourg and Ireland are missing; substituted with median for the null values (possible outside influence/biases)

# %%
prices_df[prices_df["OBS_VALUE"].isnull()]["geo"].value_counts()
prices_df['OBS_VALUE'] = prices_df.groupby('geo')['OBS_VALUE'].transform(lambda x: x.fillna(x.median()))

prices_df.head()
# Out:
#   currency                        prod_veg      geo  TIME_PERIOD  OBS_VALUE
# 0     Euro  Soft wheat - prices per 100 kg  Austria         2015      13.72
# 1     Euro  Soft wheat - prices per 100 kg  Austria         2016      11.55
# 2     Euro  Soft wheat - prices per 100 kg  Austria         2017      14.46
# 3     Euro  Soft wheat - prices per 100 kg  Austria         2018      15.41
# 4     Euro  Soft wheat - prices per 100 kg  Austria         2019      14.63

# %%
prices_df["prod_veg"] = prices_df["prod_veg"].str.replace(r"\s-\sprices.*", "", regex=True)
prices_df["TIME_PERIOD"] = prices_df["TIME_PERIOD"].astype(int)
prices_df = prices_df.rename(columns={"TIME_PERIOD": "year"})
prices_df = prices_df.rename(columns={"OBS_VALUE": "selling_price"})
prices_df.head()
# Out:
#   currency    prod_veg      geo  year  selling_price
# 0     Euro  Soft wheat  Austria  2015          13.72
# 1     Euro  Soft wheat  Austria  2016          11.55
# 2     Euro  Soft wheat  Austria  2017          14.46
# 3     Euro  Soft wheat  Austria  2018          15.41
# 4     Euro  Soft wheat  Austria  2019          14.63

# %%
fig = px.line(
    prices_df,
    x="year",
    y="selling_price",
    color="geo",
    markers=True,
    title="crop price by country",
    labels={
        "year": "Year",
        "selling_price": "price",
        "geo": "Country/area",
    },
)

fig.show()

# %%
# lat, lon of each capital city
eu_countries = {
    "Austria": (48.21, 16.37),
    "Belgium": (50.85, 4.35),
    "Bulgaria": (42.70, 23.32),
    "Croatia": (45.81, 15.98),
    "Cyprus": (35.17, 33.36),
    "Czechia": (50.08, 14.43),
    "Denmark": (55.68, 12.57),
    "Estonia": (59.44, 24.75),
    "Finland": (60.17, 24.94),
    "France": (48.85, 2.35),
    "Germany": (52.52, 13.41),
    "Greece": (37.98, 23.72),
    "Hungary": (47.50, 19.04),
    "Ireland": (53.35, -6.26),
    "Italy": (41.90, 12.50),
    "Latvia": (56.95, 24.10),
    "Lithuania": (54.68, 25.28),
    "Luxembourg": (49.61, 6.13),
    "Malta": (35.90, 14.51),
    "Netherlands": (52.37, 4.90),
    "Poland": (52.23, 21.01),
    "Portugal": (38.72, -9.14),
    "Romania": (44.43, 26.10),
    "Slovakia": (48.15, 17.11),
    "Slovenia": (46.05, 14.51),
    "Spain": (40.42, -3.70),
    "Sweden": (59.33, 18.07)
}

# %%
import requests
import pandas as pd

def get_weather(lat, lon, country, year):
    url = "https://archive-api.open-meteo.com/v1/archive"

    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": f"{year}-01-01",
        "end_date": f"{year}-12-31",
        "daily": "temperature_2m_mean,precipitation_sum",
        "timezone": "auto"
    }

    r = requests.get(url, params=params)
    data = r.json()
    df = pd.DataFrame(data["daily"])
    print(df)

    df["time"] = pd.to_datetime(df["time"])
    df["year"] = df["time"].dt.year

    yearly = df.groupby("year").agg({
        "temperature_2m_mean": "mean",
        "precipitation_sum": "sum"
    }).reset_index()

    yearly["geo"] = country

    return yearly

# %%
# all_weather = []

# for country, (lat, lon) in eu_countries.items():
#     for year in range(2015, 2025):
#         df = get_weather(lat, lon, country, year)
#         all_weather.append(df)

# weather_df = pd.concat(all_weather, ignore_index=True)
# Out:
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                  0.4                0.1
# 1    2015-01-02                  2.6                0.9
# 2    2015-01-03                  3.2                3.1
# 3    2015-01-04                  2.0                8.2
# 4    2015-01-05                  1.5                4.1
# ..          ...                  ...                ...
# 360  2015-12-27                  3.0                0.0
# 361  2015-12-28                  2.4                0.0
# 362  2015-12-29                  2.6                0.0
# 363  2015-12-30                  0.1                0.2
# 364  2015-12-31                 -3.2                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                 -1.9                0.0
# 1    2016-01-02                 -2.0                0.0
# 2    2016-01-03                 -5.3                0.0
# 3    2016-01-04                 -6.8                0.0
# 4    2016-01-05                 -5.0                0.0
# ..          ...                  ...                ...
# 361  2016-12-27                  4.8                0.5
# 362  2016-12-28                  3.4                6.3
# 363  2016-12-29                 -0.9                0.0
# 364  2016-12-30                 -2.3                0.0
# 365  2016-12-31                 -2.0                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                 -4.3                0.0
# 1    2017-01-02                 -1.7                0.2
# 2    2017-01-03                 -0.1                0.0
# 3    2017-01-04                  2.3                1.4
# 4    2017-01-05                 -2.0                0.3
# ..          ...                  ...                ...
# 360  2017-12-27                  3.5                0.0
# 361  2017-12-28                  4.3                9.4
# 362  2017-12-29                  0.9                1.8
# 363  2017-12-30                  0.2                2.5
# 364  2017-12-31                  8.3                4.2
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  3.6                0.0
# 1    2018-01-02                  4.7                0.0
# 2    2018-01-03                  3.8                2.2
# 3    2018-01-04                  6.5                3.4
# 4    2018-01-05                  7.5                8.3
# ..          ...                  ...                ...
# 360  2018-12-27                  5.3                0.0
# 361  2018-12-28                  4.8                0.4
# 362  2018-12-29                  3.1                0.0
# 363  2018-12-30                  3.9                4.3
# 364  2018-12-31                  3.8                0.5
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  5.5                0.0
# 1    2019-01-02                  2.5                1.9
# 2    2019-01-03                 -1.4                1.6
# 3    2019-01-04                 -1.8                3.2
# 4    2019-01-05                  1.7               17.2
# ..          ...                  ...                ...
# 360  2019-12-27                  3.1                0.0
# 361  2019-12-28                  1.5                0.2
# 362  2019-12-29                 -0.1                0.0
# 363  2019-12-30                 -1.2                0.0
# 364  2019-12-31                  2.5                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  1.6                0.0
# 1    2020-01-02                 -2.0                0.0
# 2    2020-01-03                 -2.0                0.0
# 3    2020-01-04                  5.0                0.6
# 4    2020-01-05                  1.4                0.8
# ..          ...                  ...                ...
# 361  2020-12-27                 -1.6                0.0
# 362  2020-12-28                  1.8                2.7
# 363  2020-12-29                  3.2                1.3
# 364  2020-12-30                  2.3                1.1
# 365  2020-12-31                  2.2                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                 -2.2                0.0
# 1    2021-01-02                  1.2                0.5
# 2    2021-01-03                  3.3                1.9
# 3    2021-01-04                  2.0                0.7
# 4    2021-01-05                  3.3                0.0
# ..          ...                  ...                ...
# 360  2021-12-27                 -1.4                0.1
# 361  2021-12-28                 -0.7                1.3
# 362  2021-12-29                  3.8                2.9
# 363  2021-12-30                  8.4                1.5
# 364  2021-12-31                 12.1                0.5
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                 11.5                0.0
# 1    2022-01-02                  7.2                0.0
# 2    2022-01-03                 10.5                0.1
# 3    2022-01-04                  7.7                0.5
# 4    2022-01-05                  6.3                2.6
# ..          ...                  ...                ...
# 360  2022-12-27                  6.5                2.7
# 361  2022-12-28                  0.7                0.0
# 362  2022-12-29                 -1.0                0.0
# 363  2022-12-30                  1.6                0.0
# 364  2022-12-31                  2.9                0.7
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                  3.2                0.0
# 1    2023-01-02                  3.3                0.0
# 2    2023-01-03                  6.4                0.7
# 3    2023-01-04                  5.0                0.4
# 4    2023-01-05                 10.9                0.3
# ..          ...                  ...                ...
# 360  2023-12-27                  7.0                0.0
# 361  2023-12-28                  3.6                0.0
# 362  2023-12-29                  7.2                0.1
# 363  2023-12-30                  7.3                0.0
# 364  2023-12-31                  1.7                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                  5.3                9.5
# 1    2024-01-02                  4.0                2.3
# 2    2024-01-03                  8.4                1.0
# 3    2024-01-04                  8.5                0.1
# 4    2024-01-05                  4.1                0.0
# ..          ...                  ...                ...
# 361  2024-12-27                  0.4                0.0
# 362  2024-12-28                  2.1                0.0
# 363  2024-12-29                  2.4                0.0
# 364  2024-12-30                  2.3                0.0
# 365  2024-12-31                 -3.4                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                  1.6                0.0
# 1    2015-01-02                  6.1                1.3
# 2    2015-01-03                  2.4               13.1
# 3    2015-01-04                  2.9                0.0
# 4    2015-01-05                  0.8                0.0
# ..          ...                  ...                ...
# 360  2015-12-27                 10.4                0.0
# 361  2015-12-28                  8.7                0.0
# 362  2015-12-29                  8.8                0.0
# 363  2015-12-30                  7.3                0.0
# 364  2015-12-31                  8.2                3.9
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                  6.2                0.3
# 1    2016-01-02                  8.2                5.1
# 2    2016-01-03                  7.4               12.1
# 3    2016-01-04                  6.7                6.1
# 4    2016-01-05                  6.0                0.7
# ..          ...                  ...                ...
# 361  2016-12-27                  4.0                0.0
# 362  2016-12-28                  1.3                0.0
# 363  2016-12-29                 -0.5                0.0
# 364  2016-12-30                 -1.1                0.0
# 365  2016-12-31                 -1.7                0.1
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                 -1.9                0.0
# 1    2017-01-02                  0.2                3.3
# 2    2017-01-03                  0.6                0.0
# 3    2017-01-04                  3.9                1.6
# 4    2017-01-05                  0.4                0.6
# ..          ...                  ...                ...
# 360  2017-12-27                  5.1                4.6
# 361  2017-12-28                  2.3                3.2
# 362  2017-12-29                  1.7                4.1
# 363  2017-12-30                  9.0                2.9
# 364  2017-12-31                 11.4               15.7
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  6.2                7.7
# 1    2018-01-02                  5.9                3.4
# 2    2018-01-03                  8.8                8.4
# 3    2018-01-04                  8.4                5.7
# 4    2018-01-05                  7.6                2.9
# ..          ...                  ...                ...
# 360  2018-12-27                  0.6                0.0
# 361  2018-12-28                  0.8                0.2
# 362  2018-12-29                  4.8                0.6
# 363  2018-12-30                  5.9                0.5
# 364  2018-12-31                  8.2                0.6
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  6.7                0.8
# 1    2019-01-02                  4.9                0.0
# 2    2019-01-03                  4.1                0.0
# 3    2019-01-04                  3.3                0.0
# 4    2019-01-05                  5.5                0.2
# ..          ...                  ...                ...
# 360  2019-12-27                  6.5                4.6
# 361  2019-12-28                  4.1                0.0
# 362  2019-12-29                  1.4                0.0
# 363  2019-12-30                  3.7                0.0
# 364  2019-12-31                  2.8                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  1.7                0.0
# 1    2020-01-02                  4.7                0.0
# 2    2020-01-03                  8.4                4.0
# 3    2020-01-04                  5.0                0.2
# 4    2020-01-05                  4.9                0.0
# ..          ...                  ...                ...
# 361  2020-12-27                  4.9               18.7
# 362  2020-12-28                  3.3                1.4
# 363  2020-12-29                  1.5                0.0
# 364  2020-12-30                  2.4                0.9
# 365  2020-12-31                  2.0                2.7
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                  0.6                0.5
# 1    2021-01-02                  1.1                0.0
# 2    2021-01-03                  2.0                0.2
# 3    2021-01-04                  1.6                2.9
# 4    2021-01-05                  1.9                0.6
# ..          ...                  ...                ...
# 360  2021-12-27                  7.6                2.3
# 361  2021-12-28                  9.3                6.8
# 362  2021-12-29                  9.5                2.5
# 363  2021-12-30                 13.2                1.0
# 364  2021-12-31                 11.9                0.3
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                 11.7                0.0
# 1    2022-01-02                 11.4                6.0
# 2    2022-01-03                  8.8                8.2
# 3    2022-01-04                  6.9               11.6
# 4    2022-01-05                  3.4                0.7
# ..          ...                  ...                ...
# 360  2022-12-27                  4.8                0.2
# 361  2022-12-28                  8.6                5.6
# 362  2022-12-29                  9.1                1.6
# 363  2022-12-30                  8.2                4.8
# 364  2022-12-31                 14.7                8.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                 12.9                4.6
# 1    2023-01-02                  9.9                7.1
# 2    2023-01-03                  6.6                0.1
# 3    2023-01-04                 10.9                3.9
# 4    2023-01-05                 10.2                0.8
# ..          ...                  ...                ...
# 360  2023-12-27                  8.3                1.8
# 361  2023-12-28                  9.6                0.1
# 362  2023-12-29                  9.5                1.9
# 363  2023-12-30                  8.0                0.3
# 364  2023-12-31                  8.7                1.6
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                  7.0                1.4
# 1    2024-01-02                 10.3               24.3
# 2    2024-01-03                  8.8                6.5
# 3    2024-01-04                  7.9                2.5
# 4    2024-01-05                  7.3                5.1
# ..          ...                  ...                ...
# 361  2024-12-27                  3.1                0.0
# 362  2024-12-28                  0.8                0.0
# 363  2024-12-29                  1.4                0.0
# 364  2024-12-30                  4.1                0.0
# 365  2024-12-31                  2.9                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                -14.2                0.0
# 1    2015-01-02                -10.1                0.0
# 2    2015-01-03                 -3.8                0.2
# 3    2015-01-04                 -1.1                0.7
# 4    2015-01-05                 -4.4                0.3
# ..          ...                  ...                ...
# 360  2015-12-27                  5.8                0.0
# 361  2015-12-28                  6.9                0.0
# 362  2015-12-29                  4.1                0.0
# 363  2015-12-30                 -1.7                0.4
# 364  2015-12-31                 -6.7                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                 -5.7                0.0
# 1    2016-01-02                 -2.5                0.1
# 2    2016-01-03                 -4.9               11.3
# 3    2016-01-04                 -5.7                8.0
# 4    2016-01-05                  1.9                3.2
# ..          ...                  ...                ...
# 361  2016-12-27                  1.7                0.3
# 362  2016-12-28                 -1.6                4.2
# 363  2016-12-29                 -3.3                2.6
# 364  2016-12-30                 -5.4                0.0
# 365  2016-12-31                 -2.3                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                 -2.7                0.0
# 1    2017-01-02                 -0.4                0.0
# 2    2017-01-03                  0.1                0.0
# 3    2017-01-04                  0.1                0.8
# 4    2017-01-05                  0.3                8.3
# ..          ...                  ...                ...
# 360  2017-12-27                  3.2                0.0
# 361  2017-12-28                  3.5                0.9
# 362  2017-12-29                  3.7                3.3
# 363  2017-12-30                  0.6                0.4
# 364  2017-12-31                  0.7                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  4.7                0.0
# 1    2018-01-02                  3.2                2.5
# 2    2018-01-03                  2.6                0.1
# 3    2018-01-04                  1.5                2.4
# 4    2018-01-05                  2.1                0.0
# ..          ...                  ...                ...
# 360  2018-12-27                  0.6                0.0
# 361  2018-12-28                  2.0                0.0
# 362  2018-12-29                  3.2                2.3
# 363  2018-12-30                  1.5                0.0
# 364  2018-12-31                  1.2                1.2
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  1.0                0.0
# 1    2019-01-02                 -0.8                0.0
# 2    2019-01-03                 -0.6                1.3
# 3    2019-01-04                 -3.0                2.6
# 4    2019-01-05                 -4.2                0.3
# ..          ...                  ...                ...
# 360  2019-12-27                  1.6                0.0
# 361  2019-12-28                 -0.7                0.6
# 362  2019-12-29                 -1.1                0.9
# 363  2019-12-30                 -1.0                0.3
# 364  2019-12-31                 -1.7                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                 -0.3                0.0
# 1    2020-01-02                 -1.1                0.0
# 2    2020-01-03                 -1.0                0.0
# 3    2020-01-04                  1.0                0.0
# 4    2020-01-05                  1.3                0.6
# ..          ...                  ...                ...
# 361  2020-12-27                  5.2                6.9
# 362  2020-12-28                  5.4                2.7
# 363  2020-12-29                  7.2                0.0
# 364  2020-12-30                  6.4                0.0
# 365  2020-12-31                  6.1                0.5
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                  4.3                0.0
# 1    2021-01-02                  2.3                0.0
# 2    2021-01-03                  4.8                1.8
# 3    2021-01-04                  6.6               24.8
# 4    2021-01-05                  6.1                5.2
# ..          ...                  ...                ...
# 360  2021-12-27                  4.1                2.8
# 361  2021-12-28                  4.1                1.7
# 362  2021-12-29                  4.8                1.4
# 363  2021-12-30                  3.8                1.5
# 364  2021-12-31                  4.8                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                  6.0                0.5
# 1    2022-01-02                  7.2                0.0
# 2    2022-01-03                  5.5                0.0
# 3    2022-01-04                  5.5                0.0
# 4    2022-01-05                  6.0                0.0
# ..          ...                  ...                ...
# 360  2022-12-27                  5.5                0.0
# 361  2022-12-28                  2.9                1.1
# 362  2022-12-29                  3.2                0.0
# 363  2022-12-30                  6.0                0.0
# 364  2022-12-31                  6.4                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                  6.3                0.0
# 1    2023-01-02                  6.1                0.0
# 2    2023-01-03                  5.6                0.0
# 3    2023-01-04                  4.5                0.0
# 4    2023-01-05                  5.4                0.0
# ..          ...                  ...                ...
# 360  2023-12-27                  4.0                0.0
# 361  2023-12-28                  5.0                0.0
# 362  2023-12-29                  5.5                0.0
# 363  2023-12-30                  3.8                0.0
# 364  2023-12-31                  3.9                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                  4.3                0.0
# 1    2024-01-02                  5.2                3.0
# 2    2024-01-03                  4.5                0.1
# 3    2024-01-04                  6.2                5.2
# 4    2024-01-05                  4.5                0.0
# ..          ...                  ...                ...
# 361  2024-12-27                  0.4                1.4
# 362  2024-12-28                  1.5                0.0
# 363  2024-12-29                 -0.8                0.0
# 364  2024-12-30                  1.0                0.0
# 365  2024-12-31                  1.7                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                -11.2                0.0
# 1    2015-01-02                 -2.2                0.2
# 2    2015-01-03                  0.3                1.6
# 3    2015-01-04                  1.4                1.1
# 4    2015-01-05                 -0.8                0.6
# ..          ...                  ...                ...
# 360  2015-12-27                  2.4                0.0
# 361  2015-12-28                  0.1                0.0
# 362  2015-12-29                  0.8                0.1
# 363  2015-12-30                  1.2                0.1
# 364  2015-12-31                 -2.3                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                 -1.3                0.0
# 1    2016-01-02                 -1.5                5.7
# 2    2016-01-03                 -4.1                8.8
# 3    2016-01-04                 -9.2                4.6
# 4    2016-01-05                 -6.1                6.3
# ..          ...                  ...                ...
# 361  2016-12-27                  1.6                2.0
# 362  2016-12-28                  0.7                4.7
# 363  2016-12-29                  0.1                0.0
# 364  2016-12-30                 -1.4                0.0
# 365  2016-12-31                 -1.3                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                 -1.2                0.0
# 1    2017-01-02                  0.5                0.3
# 2    2017-01-03                 -0.6                2.6
# 3    2017-01-04                 -2.7                2.1
# 4    2017-01-05                 -1.2                0.8
# ..          ...                  ...                ...
# 360  2017-12-27                  6.6                0.2
# 361  2017-12-28                  5.6               14.6
# 362  2017-12-29                  2.2                0.7
# 363  2017-12-30                  0.8                0.0
# 364  2017-12-31                  4.0                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  6.9                7.0
# 1    2018-01-02                  4.3                7.0
# 2    2018-01-03                  2.6                2.7
# 3    2018-01-04                  2.5                0.0
# 4    2018-01-05                  6.9                0.5
# ..          ...                  ...                ...
# 360  2018-12-27                  1.0                0.0
# 361  2018-12-28                  1.0                0.0
# 362  2018-12-29                  1.8                0.2
# 363  2018-12-30                  1.1                0.1
# 364  2018-12-31                  1.1                3.4
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  0.2                0.0
# 1    2019-01-02                  1.0                1.2
# 2    2019-01-03                 -0.3                1.2
# 3    2019-01-04                 -1.7                0.4
# 4    2019-01-05                 -1.1                1.7
# ..          ...                  ...                ...
# 360  2019-12-27                  2.7                0.9
# 361  2019-12-28                  1.4                0.3
# 362  2019-12-29                  0.5                0.0
# 363  2019-12-30                 -1.7                0.0
# 364  2019-12-31                 -0.4                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  1.4                0.0
# 1    2020-01-02                  1.2                0.0
# 2    2020-01-03                  1.5                0.0
# 3    2020-01-04                  1.2                1.4
# 4    2020-01-05                  1.3                0.0
# ..          ...                  ...                ...
# 361  2020-12-27                 -0.5                0.1
# 362  2020-12-28                  2.3               14.6
# 363  2020-12-29                  6.0                4.6
# 364  2020-12-30                  5.1                2.9
# 365  2020-12-31                  3.1                2.8
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                  2.3                0.0
# 1    2021-01-02                  4.8                2.3
# 2    2021-01-03                  4.4                3.0
# 3    2021-01-04                  4.4                1.4
# 4    2021-01-05                  4.1                2.2
# ..          ...                  ...                ...
# 360  2021-12-27                  0.4                1.9
# 361  2021-12-28                  0.2                0.0
# 362  2021-12-29                  5.0                3.8
# 363  2021-12-30                  5.1                0.9
# 364  2021-12-31                  5.2                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                  6.0                0.0
# 1    2022-01-02                  3.2                0.0
# 2    2022-01-03                  4.3                0.0
# 3    2022-01-04                  7.3                0.0
# 4    2022-01-05                 10.2                9.8
# ..          ...                  ...                ...
# 360  2022-12-27                  8.6                1.3
# 361  2022-12-28                  5.0                0.0
# 362  2022-12-29                  5.6                0.0
# 363  2022-12-30                  8.8                2.0
# 364  2022-12-31                  9.5                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                  9.5                0.0
# 1    2023-01-02                  9.0                0.0
# 2    2023-01-03                  8.8                2.3
# 3    2023-01-04                  7.9                0.0
# 4    2023-01-05                  6.7                0.0
# ..          ...                  ...                ...
# 360  2023-12-27                  4.4                0.0
# 361  2023-12-28                  5.2                0.0
# 362  2023-12-29                  6.6                0.0
# 363  2023-12-30                  7.3                0.0
# 364  2023-12-31                  7.3                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                  6.9                9.8
# 1    2024-01-02                  4.0                0.0
# 2    2024-01-03                  9.1                0.4
# 3    2024-01-04                  7.7                0.0
# 4    2024-01-05                  5.0                0.0
# ..          ...                  ...                ...
# 361  2024-12-27                  0.4                0.0
# 362  2024-12-28                  1.3                0.0
# 363  2024-12-29                  1.4                0.0
# 364  2024-12-30                  1.2                0.0
# 365  2024-12-31                 -0.6                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                 12.4                3.9
# 1    2015-01-02                 12.1                3.8
# 2    2015-01-03                 10.6                3.4
# 3    2015-01-04                 11.3                0.0
# 4    2015-01-05                 12.9               10.8
# ..          ...                  ...                ...
# 360  2015-12-27                 13.6                0.0
# 361  2015-12-28                 14.1                0.0
# 362  2015-12-29                 13.9                0.0
# 363  2015-12-30                 11.8                0.0
# 364  2015-12-31                  7.6                0.7
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                  5.1                0.8
# 1    2016-01-02                  5.6                0.0
# 2    2016-01-03                  7.8                0.0
# 3    2016-01-04                  9.7               13.7
# 4    2016-01-05                 12.6                0.6
# ..          ...                  ...                ...
# 361  2016-12-27                  9.7                1.7
# 362  2016-12-28                 10.0                0.0
# 363  2016-12-29                 12.4                9.1
# 364  2016-12-30                 10.3                6.9
# 365  2016-12-31                  8.6                0.3
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                  8.3                0.7
# 1    2017-01-02                  8.2                0.7
# 2    2017-01-03                  8.2                0.0
# 3    2017-01-04                  8.5                0.1
# 4    2017-01-05                  9.5                0.2
# ..          ...                  ...                ...
# 360  2017-12-27                 12.6                0.0
# 361  2017-12-28                 13.9                0.0
# 362  2017-12-29                 13.3                0.7
# 363  2017-12-30                 12.2                0.3
# 364  2017-12-31                 11.6                0.3
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                 10.8                0.0
# 1    2018-01-02                 13.3                0.0
# 2    2018-01-03                 13.2                2.6
# 3    2018-01-04                 11.6                0.2
# 4    2018-01-05                 11.5               25.9
# ..          ...                  ...                ...
# 360  2018-12-27                  9.7                8.7
# 361  2018-12-28                  8.6                0.0
# 362  2018-12-29                  9.3                0.0
# 363  2018-12-30                  8.5                0.9
# 364  2018-12-31                  9.5                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                 10.2                9.7
# 1    2019-01-02                 10.1                0.7
# 2    2019-01-03                 10.5                0.3
# 3    2019-01-04                 12.7                1.2
# 4    2019-01-05                 11.0                0.6
# ..          ...                  ...                ...
# 360  2019-12-27                 10.5                0.5
# 361  2019-12-28                 10.5                2.4
# 362  2019-12-29                 10.5                1.2
# 363  2019-12-30                 10.9                6.5
# 364  2019-12-31                  9.5                0.3
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  9.4                0.7
# 1    2020-01-02                 10.4                3.2
# 2    2020-01-03                  9.7                3.7
# 3    2020-01-04                  9.1                0.3
# 4    2020-01-05                 10.5                0.0
# ..          ...                  ...                ...
# 361  2020-12-27                 12.0                0.0
# 362  2020-12-28                 13.1                0.0
# 363  2020-12-29                 13.2                0.0
# 364  2020-12-30                 12.4                0.0
# 365  2020-12-31                 12.2                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                 12.4                0.0
# 1    2021-01-02                 13.6                0.1
# 2    2021-01-03                 13.7                0.0
# 3    2021-01-04                 13.9                0.0
# 4    2021-01-05                 14.2                0.0
# ..          ...                  ...                ...
# 360  2021-12-27                 12.3                0.4
# 361  2021-12-28                 11.6                0.0
# 362  2021-12-29                 11.0                0.0
# 363  2021-12-30                 11.1                8.5
# 364  2021-12-31                 12.4               18.9
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                 13.1                0.0
# 1    2022-01-02                 12.1                0.0
# 2    2022-01-03                 12.2                0.0
# 3    2022-01-04                 11.6                0.0
# 4    2022-01-05                 13.4                0.2
# ..          ...                  ...                ...
# 360  2022-12-27                 11.6                0.0
# 361  2022-12-28                 10.9                0.0
# 362  2022-12-29                 12.1                0.0
# 363  2022-12-30                 12.3                0.4
# 364  2022-12-31                 12.0                0.1
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                 11.8                0.0
# 1    2023-01-02                 13.0                0.0
# 2    2023-01-03                 12.9                0.0
# 3    2023-01-04                 12.5                0.0
# 4    2023-01-05                 11.7                0.0
# ..          ...                  ...                ...
# 360  2023-12-27                 14.1                0.0
# 361  2023-12-28                 13.7                0.0
# 362  2023-12-29                 13.5                0.0
# 363  2023-12-30                 13.6                0.0
# 364  2023-12-31                 12.9                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                 13.4                1.1
# 1    2024-01-02                 13.7                0.5
# 2    2024-01-03                 14.2                0.0
# 3    2024-01-04                 13.1                0.0
# 4    2024-01-05                 15.0                0.0
# ..          ...                  ...                ...
# 361  2024-12-27                  9.7                7.5
# 362  2024-12-28                  9.6                0.5
# 363  2024-12-29                  9.3                2.7
# 364  2024-12-30                  8.6                2.4
# 365  2024-12-31                  9.8                2.7
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                  2.1                1.3
# 1    2015-01-02                  2.7                1.9
# 2    2015-01-03                  2.2                1.1
# 3    2015-01-04                  2.0                2.8
# 4    2015-01-05                  1.6                3.8
# ..          ...                  ...                ...
# 360  2015-12-27                  7.9                0.0
# 361  2015-12-28                  8.0                0.0
# 362  2015-12-29                  5.5                0.0
# 363  2015-12-30                  2.6                0.0
# 364  2015-12-31                 -1.4                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                 -0.3                0.9
# 1    2016-01-02                 -0.3                0.0
# 2    2016-01-03                 -3.0                0.0
# 3    2016-01-04                 -4.3                2.0
# 4    2016-01-05                 -1.0                2.4
# ..          ...                  ...                ...
# 361  2016-12-27                  4.0                1.6
# 362  2016-12-28                  4.5               17.4
# 363  2016-12-29                  0.9                0.0
# 364  2016-12-30                 -2.2                0.0
# 365  2016-12-31                 -3.3                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                 -2.9                0.0
# 1    2017-01-02                 -1.9                1.2
# 2    2017-01-03                 -0.3                0.2
# 3    2017-01-04                  1.2                3.7
# 4    2017-01-05                 -3.8                1.9
# ..          ...                  ...                ...
# 360  2017-12-27                  0.6                0.0
# 361  2017-12-28                  1.1                5.2
# 362  2017-12-29                 -0.6                0.0
# 363  2017-12-30                  1.4                3.1
# 364  2017-12-31                  8.5                3.6
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  6.0                0.0
# 1    2018-01-02                  4.2                0.4
# 2    2018-01-03                  4.1                5.8
# 3    2018-01-04                  5.5                3.5
# 4    2018-01-05                  7.3                2.3
# ..          ...                  ...                ...
# 360  2018-12-27                  4.3                0.4
# 361  2018-12-28                  4.2                0.4
# 362  2018-12-29                  3.4                1.4
# 363  2018-12-30                  4.1                4.9
# 364  2018-12-31                  3.9                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  5.7                1.0
# 1    2019-01-02                  1.0                1.0
# 2    2019-01-03                 -2.1                1.7
# 3    2019-01-04                 -1.2                1.6
# 4    2019-01-05                  3.6                7.1
# ..          ...                  ...                ...
# 360  2019-12-27                  1.0                0.0
# 361  2019-12-28                  0.4                1.3
# 362  2019-12-29                 -1.3                0.0
# 363  2019-12-30                 -0.1                0.0
# 364  2019-12-31                  3.2                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  0.7                0.0
# 1    2020-01-02                 -3.2                0.0
# 2    2020-01-03                  1.4                0.1
# 3    2020-01-04                  3.7                2.1
# 4    2020-01-05                  0.6                0.1
# ..          ...                  ...                ...
# 361  2020-12-27                 -1.0                0.0
# 362  2020-12-28                  0.9                0.1
# 363  2020-12-29                  2.3                0.2
# 364  2020-12-30                  0.4                0.0
# 365  2020-12-31                 -0.1                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                 -1.6                0.3
# 1    2021-01-02                 -1.9                0.0
# 2    2021-01-03                  2.4                2.7
# 3    2021-01-04                  2.3                1.5
# 4    2021-01-05                  1.7                1.9
# ..          ...                  ...                ...
# 360  2021-12-27                 -3.0                0.0
# 361  2021-12-28                  0.1                4.0
# 362  2021-12-29                  3.9                1.2
# 363  2021-12-30                  8.0                1.6
# 364  2021-12-31                 11.0                0.9
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                 10.2                0.2
# 1    2022-01-02                  7.3                0.0
# 2    2022-01-03                  8.8                4.6
# 3    2022-01-04                  8.1                7.2
# 4    2022-01-05                  3.6                2.4
# ..          ...                  ...                ...
# 360  2022-12-27                  3.9                4.4
# 361  2022-12-28                  3.4                0.1
# 362  2022-12-29                  7.7                0.6
# 363  2022-12-30                  6.8                1.1
# 364  2022-12-31                 12.1                0.3
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                 12.2                0.0
# 1    2023-01-02                  8.7                0.0
# 2    2023-01-03                  6.7                0.0
# 3    2023-01-04                  4.9                5.0
# 4    2023-01-05                  9.3                3.6
# ..          ...                  ...                ...
# 360  2023-12-27                  4.9                0.0
# 361  2023-12-28                  6.2                8.0
# 362  2023-12-29                  8.8                0.0
# 363  2023-12-30                  7.9                0.3
# 364  2023-12-31                  3.8                0.1
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                  5.1                1.8
# 1    2024-01-02                  4.9               12.8
# 2    2024-01-03                  9.0                2.9
# 3    2024-01-04                  7.1               13.9
# 4    2024-01-05                  4.3                0.6
# ..          ...                  ...                ...
# 361  2024-12-27                 -3.8                0.0
# 362  2024-12-28                 -3.5                0.0
# 363  2024-12-29                 -1.1                0.0
# 364  2024-12-30                 -0.7                0.0
# 365  2024-12-31                 -0.5                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                  4.9                0.7
# 1    2015-01-02                  6.2                2.2
# 2    2015-01-03                  4.3                0.0
# 3    2015-01-04                  2.9                0.0
# 4    2015-01-05                  2.4                1.2
# ..          ...                  ...                ...
# 360  2015-12-27                  6.7               14.1
# 361  2015-12-28                  4.1                0.0
# 362  2015-12-29                  3.5                0.0
# 363  2015-12-30                  2.6                0.0
# 364  2015-12-31                  2.0                2.2
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                  4.1                0.5
# 1    2016-01-02                 -1.0                0.0
# 2    2016-01-03                 -3.2                0.0
# 3    2016-01-04                 -2.7                0.0
# 4    2016-01-05                 -3.3                0.0
# ..          ...                  ...                ...
# 361  2016-12-27                  5.7                0.1
# 362  2016-12-28                  4.2                0.0
# 363  2016-12-29                  3.2                0.0
# 364  2016-12-30                  3.0                0.0
# 365  2016-12-31                  6.8                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                  5.9                1.7
# 1    2017-01-02                  1.2                0.0
# 2    2017-01-03                  2.8                4.4
# 3    2017-01-04                  1.7                0.1
# 4    2017-01-05                 -4.9                0.0
# ..          ...                  ...                ...
# 360  2017-12-27                  4.5                2.6
# 361  2017-12-28                  3.9                1.0
# 362  2017-12-29                  3.2                0.0
# 363  2017-12-30                  3.3                3.6
# 364  2017-12-31                  4.1                5.8
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  5.9                3.9
# 1    2018-01-02                  4.1                0.0
# 2    2018-01-03                  3.8               13.7
# 3    2018-01-04                  3.3                1.8
# 4    2018-01-05                  3.1                2.6
# ..          ...                  ...                ...
# 360  2018-12-27                  7.3                2.4
# 361  2018-12-28                  5.6                0.0
# 362  2018-12-29                  6.6                3.7
# 363  2018-12-30                  4.6                0.3
# 364  2018-12-31                  4.5                1.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  6.6                0.5
# 1    2019-01-02                  3.0                0.0
# 2    2019-01-03                  2.1                0.0
# 3    2019-01-04                  3.9                0.0
# 4    2019-01-05                  4.9                0.0
# ..          ...                  ...                ...
# 360  2019-12-27                  1.8                0.0
# 361  2019-12-28                 -0.8                0.0
# 362  2019-12-29                  2.5                0.0
# 363  2019-12-30                  6.8                0.0
# 364  2019-12-31                  5.7                0.3
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  3.8                0.0
# 1    2020-01-02                  1.7                0.0
# 2    2020-01-03                  5.1                1.9
# 3    2020-01-04                  4.5                7.8
# 4    2020-01-05                  3.0                0.0
# ..          ...                  ...                ...
# 361  2020-12-27                  4.1                5.1
# 362  2020-12-28                  4.2                1.6
# 363  2020-12-29                  3.9                5.2
# 364  2020-12-30                  3.8                4.6
# 365  2020-12-31                  3.9                2.5
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                  2.8                1.8
# 1    2021-01-02                  1.5                0.0
# 2    2021-01-03                  2.0                0.0
# 3    2021-01-04                  0.8                0.0
# 4    2021-01-05                  1.8                0.0
# ..          ...                  ...                ...
# 360  2021-12-27                  0.2                0.0
# 361  2021-12-28                  1.3                1.3
# 362  2021-12-29                  2.3                0.0
# 363  2021-12-30                  5.2                1.0
# 364  2021-12-31                  8.0               11.3
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                  6.5                0.9
# 1    2022-01-02                  8.0               15.0
# 2    2022-01-03                  6.3                0.8
# 3    2022-01-04                  3.7                4.3
# 4    2022-01-05                  2.2                1.1
# ..          ...                  ...                ...
# 360  2022-12-27                  3.0                0.0
# 361  2022-12-28                  5.3                7.3
# 362  2022-12-29                  7.4                6.6
# 363  2022-12-30                  6.0                1.3
# 364  2022-12-31                  8.6                5.4
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                  9.4                6.2
# 1    2023-01-02                  7.2                8.6
# 2    2023-01-03                  4.7                0.0
# 3    2023-01-04                  6.8               19.8
# 4    2023-01-05                  4.9                3.4
# ..          ...                  ...                ...
# 360  2023-12-27                  2.9                0.4
# 361  2023-12-28                  6.8                6.2
# 362  2023-12-29                  6.8                3.9
# 363  2023-12-30                  4.3                0.4
# 364  2023-12-31                  4.7                5.9
# ...
# 0    2022-01-01                  0.7                0.0
# 1    2022-01-02                  2.5                0.0
# 2    2022-01-03                  3.6                0.0
# 3    2022-01-04                  4.7                1.5
# 4    2022-01-05                  7.1               12.6
# ..          ...                  ...                ...
# 360  2022-12-27                  8.4                0.9
# 361  2022-12-28                  4.2                0.0
# 362  2022-12-29                  5.7                1.0
# 363  2022-12-30                  8.1                5.1
# 364  2022-12-31                  9.3                0.1
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                 10.0                0.0
# 1    2023-01-02                 10.0                0.0
# 2    2023-01-03                  8.6                0.1
# 3    2023-01-04                  7.5                0.2
# 4    2023-01-05                  8.1                0.0
# ..          ...                  ...                ...
# 360  2023-12-27                  4.4                0.0
# 361  2023-12-28                  6.8                0.0
# 362  2023-12-29                  6.5                0.1
# 363  2023-12-30                  6.1                0.1
# 364  2023-12-31                  6.8                1.4
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                  6.4               25.2
# 1    2024-01-02                  3.8                0.3
# 2    2024-01-03                  6.9                1.1
# 3    2024-01-04                  6.8                0.3
# 4    2024-01-05                  4.0                6.0
# ..          ...                  ...                ...
# 361  2024-12-27                 -2.3                0.0
# 362  2024-12-28                 -1.0                0.0
# 363  2024-12-29                  0.2                0.0
# 364  2024-12-30                 -0.4                0.0
# 365  2024-12-31                 -1.1                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                  2.1                0.0
# 1    2015-01-02                  2.3                0.0
# 2    2015-01-03                  3.1                0.0
# 3    2015-01-04                  4.0                0.0
# 4    2015-01-05                  4.3                0.0
# ..          ...                  ...                ...
# 360  2015-12-27                  6.0                0.0
# 361  2015-12-28                  7.9                0.6
# 362  2015-12-29                  8.7                0.5
# 363  2015-12-30                  6.6                0.0
# 364  2015-12-31                  9.2                0.8
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                  8.8                1.4
# 1    2016-01-02                  8.3                1.1
# 2    2016-01-03                  6.4                0.0
# 3    2016-01-04                 11.0                8.9
# 4    2016-01-05                  5.3                0.4
# ..          ...                  ...                ...
# 361  2016-12-27                  5.8                0.0
# 362  2016-12-28                  6.6                0.0
# 363  2016-12-29                  5.7                0.0
# 364  2016-12-30                  3.4                0.0
# 365  2016-12-31                 -0.2                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                 -0.8                0.0
# 1    2017-01-02                  1.3                0.0
# 2    2017-01-03                  4.0                0.7
# 3    2017-01-04                  5.3                0.0
# 4    2017-01-05                  5.2                0.0
# ..          ...                  ...                ...
# 360  2017-12-27                  7.5                2.7
# 361  2017-12-28                  8.3                1.6
# 362  2017-12-29                 10.1                0.0
# 363  2017-12-30                 10.5                0.0
# 364  2017-12-31                  8.0                1.6
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  6.0                0.0
# 1    2018-01-02                  8.4                0.0
# 2    2018-01-03                 10.2                0.0
# 3    2018-01-04                 10.0                0.0
# 4    2018-01-05                  9.0                5.4
# ..          ...                  ...                ...
# 360  2018-12-27                  3.1                0.0
# 361  2018-12-28                  4.4                0.0
# 362  2018-12-29                  6.1                0.0
# 363  2018-12-30                  5.7                0.0
# 364  2018-12-31                  5.1                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  3.1                0.0
# 1    2019-01-02                  2.5                0.0
# 2    2019-01-03                  3.6                0.0
# 3    2019-01-04                  2.9                0.0
# 4    2019-01-05                  2.0                0.0
# ..          ...                  ...                ...
# 360  2019-12-27                  6.1                0.0
# 361  2019-12-28                  5.9                0.0
# 362  2019-12-29                  4.5                0.0
# 363  2019-12-30                  4.0                0.0
# 364  2019-12-31                  4.3                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  3.6                0.0
# 1    2020-01-02                  2.7                0.0
# 2    2020-01-03                  1.5                0.0
# 3    2020-01-04                  4.5                0.0
# 4    2020-01-05                  4.2                0.0
# ..          ...                  ...                ...
# 361  2020-12-27                  1.6                0.0
# 362  2020-12-28                  5.7                2.7
# 363  2020-12-29                  3.2                0.2
# 364  2020-12-30                  3.2                0.0
# 365  2020-12-31                  2.1                1.3
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                  3.6                3.6
# 1    2021-01-02                  1.7                0.0
# 2    2021-01-03                  1.4                0.0
# 3    2021-01-04                  1.6                0.1
# 4    2021-01-05                 -0.3                0.0
# ..          ...                  ...                ...
# 360  2021-12-27                 12.0                0.1
# 361  2021-12-28                 10.2                0.0
# 362  2021-12-29                  7.8                0.0
# 363  2021-12-30                  6.6                0.0
# 364  2021-12-31                  6.7                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                  7.8                0.0
# 1    2022-01-02                  6.6                0.0
# 2    2022-01-03                  6.6                0.0
# 3    2022-01-04                  7.1                7.5
# 4    2022-01-05                  6.2                5.3
# ..          ...                  ...                ...
# 360  2022-12-27                  7.5                0.0
# 361  2022-12-28                  7.1                0.0
# 362  2022-12-29                  9.3                2.7
# 363  2022-12-30                 10.8                0.0
# 364  2022-12-31                  7.6                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                  8.5                0.0
# 1    2023-01-02                  9.0                1.1
# 2    2023-01-03                  7.0                0.0
# 3    2023-01-04                  5.0                0.0
# 4    2023-01-05                  4.7                0.0
# ..          ...                  ...                ...
# 360  2023-12-27                  3.1                0.0
# 361  2023-12-28                  2.5                0.0
# 362  2023-12-29                  3.4                0.9
# 363  2023-12-30                  4.1                0.0
# 364  2023-12-31                  6.9                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                  5.0                0.0
# 1    2024-01-02                  5.4                0.1
# 2    2024-01-03                 10.6                2.0
# 3    2024-01-04                  9.4                9.6
# 4    2024-01-05                  6.6                1.0
# ..          ...                  ...                ...
# 361  2024-12-27                  5.9                0.0
# 362  2024-12-28                  4.4                0.0
# 363  2024-12-29                  4.0                0.0
# 364  2024-12-30                  3.3                0.0
# 365  2024-12-31                  3.1                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2015-01-01                  3.5                0.0
# 1    2015-01-02                  4.7                2.0
# 2    2015-01-03                  1.7                0.0
# 3    2015-01-04                 -0.3                0.0
# 4    2015-01-05                 -1.6                0.0
# ..          ...                  ...                ...
# 360  2015-12-27                 -1.1                3.1
# 361  2015-12-28                 -0.1                0.6
# 362  2015-12-29                 -0.7                0.0
# 363  2015-12-30                  1.3                0.0
# 364  2015-12-31                  1.6                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2016-01-01                  0.8                0.0
# 1    2016-01-02                 -2.4                0.0
# 2    2016-01-03                 -3.8                0.0
# 3    2016-01-04                 -5.1                0.0
# 4    2016-01-05                 -5.9                0.0
# ..          ...                  ...                ...
# 361  2016-12-27                  2.0                0.9
# 362  2016-12-28                 -0.3                0.0
# 363  2016-12-29                  2.6                0.0
# 364  2016-12-30                  5.5                0.0
# 365  2016-12-31                  9.2                0.1
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2017-01-01                  3.1                1.2
# 1    2017-01-02                 -2.3                0.2
# 2    2017-01-03                 -3.9                5.6
# 3    2017-01-04                 -4.4                5.5
# 4    2017-01-05                -13.2                0.0
# ..          ...                  ...                ...
# 360  2017-12-27                  2.2                0.4
# 361  2017-12-28                  3.9                1.7
# 362  2017-12-29                  2.0                2.1
# 363  2017-12-30                  0.6                0.0
# 364  2017-12-31                  1.4                1.3
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2018-01-01                  2.4                5.9
# 1    2018-01-02                  2.5                0.7
# 2    2018-01-03                  2.2                0.5
# 3    2018-01-04                  2.4                6.8
# 4    2018-01-05                  1.1                2.6
# ..          ...                  ...                ...
# 360  2018-12-27                 -0.6                0.0
# 361  2018-12-28                 -1.8                0.0
# 362  2018-12-29                 -1.7                0.0
# 363  2018-12-30                 -1.7                0.3
# 364  2018-12-31                 -0.6                0.6
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2019-01-01                  2.8                1.7
# 1    2019-01-02                 -1.6                1.0
# 2    2019-01-03                 -2.9                0.3
# 3    2019-01-04                  2.3                2.1
# 4    2019-01-05                  0.5                0.4
# ..          ...                  ...                ...
# 360  2019-12-27                 -0.3                0.1
# 361  2019-12-28                 -3.3                0.0
# 362  2019-12-29                  2.2                0.3
# 363  2019-12-30                  6.9                0.0
# 364  2019-12-31                  3.0                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2020-01-01                  2.6                0.0
# 1    2020-01-02                  5.1                0.0
# 2    2020-01-03                  5.3                0.0
# 3    2020-01-04                  1.7                0.0
# 4    2020-01-05                 -0.7                2.7
# ..          ...                  ...                ...
# 361  2020-12-27                  3.5                3.8
# 362  2020-12-28                  3.5                6.4
# 363  2020-12-29                  3.9                9.3
# 364  2020-12-30                  2.2                4.5
# 365  2020-12-31                  1.0                0.0
#
# [366 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2021-01-01                  0.2                2.6
# 1    2021-01-02                  0.9                2.7
# 2    2021-01-03                 -0.8                0.0
# 3    2021-01-04                  0.1                0.8
# 4    2021-01-05                 -0.2                0.1
# ..          ...                  ...                ...
# 360  2021-12-27                 -5.9                0.0
# 361  2021-12-28                 -1.5                0.6
# 362  2021-12-29                 -0.4                6.8
# 363  2021-12-30                  1.4                1.8
# 364  2021-12-31                  2.0                0.1
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2022-01-01                 -1.5                0.8
# 1    2022-01-02                  1.8                7.2
# 2    2022-01-03                  2.9                2.0
# 3    2022-01-04                  0.6                0.9
# 4    2022-01-05                 -1.7                0.8
# ..          ...                  ...                ...
# 360  2022-12-27                  0.4                3.2
# 361  2022-12-28                 -2.1                0.4
# 362  2022-12-29                  3.1                4.5
# 363  2022-12-30                  3.9                0.0
# 364  2022-12-31                  5.1                1.8
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2023-01-01                 -1.2                0.0
# 1    2023-01-02                  1.1                6.5
# 2    2023-01-03                 -2.6                1.6
# 3    2023-01-04                 -3.5                3.2
# 4    2023-01-05                 -2.3                2.9
# ..          ...                  ...                ...
# 360  2023-12-27                 -5.5                0.0
# 361  2023-12-28                 -2.5                3.6
# 362  2023-12-29                  1.3                5.7
# 363  2023-12-30                 -0.1                1.5
# 364  2023-12-31                 -3.9                0.0
#
# [365 rows x 3 columns]
#            time  temperature_2m_mean  precipitation_sum
# 0    2024-01-01                 -3.2                0.8
# 1    2024-01-02                 -5.8                3.3
# 2    2024-01-03                 -7.4                1.1
# 3    2024-01-04                 -8.0                2.8
# 4    2024-01-05                -10.0                0.0
# ..          ...                  ...                ...
# 361  2024-12-27                  5.3                0.0
# 362  2024-12-28                  4.9                1.5
# 363  2024-12-29                  6.0                1.5
# 364  2024-12-30                  2.7                1.2
# 365  2024-12-31                 -2.6                0.9
#
# [366 rows x 3 columns]

# %%
# weather_df.to_csv(r"C:\Users\npste\Farmers-Market\datasets\weather.csv", index=False)

# %%
weather_df = pd.read_csv(r"C:\Users\npste\Farmers-Market\datasets\weather.csv")

# %%
merged_df = prices_df.merge(
    weather_df,
    on=["geo", "year"],
    how="left"
)

# %%
merged_df.head()
# Out:
#   currency    prod_veg      geo  year  selling_price  temperature_2m_mean  \
# 0     Euro  Soft wheat  Austria  2015          13.72            11.941370
# 1     Euro  Soft wheat  Austria  2016          11.55            11.251913
# 2     Euro  Soft wheat  Austria  2017          14.46            11.234795
# 3     Euro  Soft wheat  Austria  2018          15.41            12.166027
# 4     Euro  Soft wheat  Austria  2019          14.63            12.056712
#
#    precipitation_sum
# 0              561.2
# 1              704.2
# 2              527.5
# 3              614.9
# 4              614.0

# %%
merged_df = merged_df[~merged_df["geo"].isin(["United Kingdom", "Kosovo*"])]
merged_df.isna().sum()
# Out:
# currency               0
# prod_veg               0
# geo                    0
# year                   0
# selling_price          0
# temperature_2m_mean    0
# precipitation_sum      0
# dtype: int64

# %% [markdown]
# ## Data Visualizations

# %%
sns.heatmap(merged_df[['selling_price','year',
  'temperature_2m_mean','precipitation_sum']].corr(),
  annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: >

# %%
plt.scatter(merged_df['precipitation_sum'], merged_df['selling_price'])
plt.ylabel('price')
plt.xlabel('precip sum')
plt.suptitle('Relationship between precip sum and price')
plt.gcf().set_size_inches(6, 3)

# %%
merged_df[['selling_price', 'precipitation_sum']].describe()
# Out:
#        selling_price  precipitation_sum
# count     989.000000         989.000000
# mean       18.737983         697.579575
# std         6.276703         212.781518
# min         9.730000         195.900000
# 25%        14.370000         561.200000
# 50%        16.810000         680.700000
# 75%        21.550000         804.200000
# max        51.450000        1601.000000

# %%
plt.scatter(merged_df['temperature_2m_mean'], merged_df['selling_price'])
plt.ylabel('price')
plt.xlabel('temp')
plt.suptitle('Relationship between temp and price')
plt.gcf().set_size_inches(6, 3)

# %%
fig = px.scatter(
    merged_df,
    x="temperature_2m_mean",
    y="selling_price",
    color="geo",
    title="temp vs price by country",
    labels={
        "temperature_2m_mean": "temp",
        "selling_price": "price",
        "geo": "Country/area",
    },
)

fig.show()

# %%
avg = merged_df.groupby(['year','prod_veg'])['selling_price'].mean().reset_index()

fig = px.line(avg, x='year', y='selling_price',
    color='prod_veg', markers=True,
    title='Average selling price over time by crop')
fig.show()

# %% [markdown]
# ## Linear Regression Models

# %% [markdown]
# ### Set up funcs

# %%
def add_bias_column(X):
    """
    Args:
        X (array): can be either 1-d or 2-d
    
    Returns:
        Xnew (array): the same array, but 2-d with a column of 1's in the first spot
    """
    
    # If the array is 1-d
    if len(X.shape) == 1:
        Xnew = np.column_stack([np.ones(X.shape[0]), X])
    
    # If the array is 2-d
    elif len(X.shape) == 2:
        bias_col = np.ones((X.shape[0], 1))
        Xnew = np.hstack([bias_col, X])
        
    else:
        raise ValueError("Input array must be either 1-d or 2-d")

    return Xnew

# %%
def line_of_best_fit(X,y):
    """"
    Finds coefficients of line of best fit

    Args:
        X (array): predictor values
        Y (array): response values
    
    Returns:
        m (array): coefficients for the line of best fit, including intercept
    """
    newX = add_bias_column(X)
    XtXinv = np.linalg.inv(newX.T @ newX)
    m = XtXinv @ (newX.T @ y)


    return m

# %%
def linreg_predict(Xnew,Ynew,b):
    """ Returns predicted values, resids, mse, r2

    Args:
        Xnew (array): predictor features
        Ynew (array): response values
        b (array): line of best fit coefficients

    Returns:
        dict (dictionary): contains ypreds, resids, mse, r2
    """
    newX = add_bias_column(Xnew)
    ypreds = newX @ b
    res = ypreds - Ynew
    mse = (res**2).mean()
    r2 = 1 - (mse/Ynew.var())
    dict = {"ypreds": ypreds, "resids": res, "mse": mse, "r2": r2}
    return dict

# %%
sns.set()

def get_mse(y_true, y_pred):
    """ gets the MSE

    Args:
        y_true (array): the true y values
        y_pred (array): the predicted y values

    Returns:
        the mean squared error

    """
    
    return np.mean((y_true - y_pred) ** 2)

def show_fit(X, y, slope, intercept):
    """ plots a simple linear regression line through x y points and prints the slope, intercept, and MSE

    Args:
        X (array): the design matrix
        y (array): the response variable
        slope (float): the slope
        intercept (float): the intercept

    Returns:
        A plot (I'm getting lazy with these...)
    """
    
    plt.figure()
    
    # in case this wasn't done before, transform the input data into numpy arrays and flatten them
    x = np.array(X).ravel()
    y = np.array(y).ravel()
    
    # plot the actual data
    plt.scatter(x, y, label='data')
    
    # compute linear predictions 
    # x is a numpy array so each element gets multiplied by slope and intercept is added
    y_pred = slope * x + intercept
    
    # plot the linear fit
    plt.plot(x, y_pred, color='black',
             ls=':',
             label='linear fit')
    
    plt.legend()
    
    plt.xlabel('x')
    plt.ylabel('y')
    
    # print the mean squared error
    y_pred = slope * x + intercept
    mse = get_mse(y_true=y, y_pred=y_pred)
    plt.suptitle(f'y_hat = {slope:.3f} * x + {intercept:.3f}, MSE = {mse:.3f}')

# %% [markdown]
# ### Simple model - no time series

# %%
import numpy as np

# Single-fold cross validation
# note, I'm not scaling anything here, but if I did I would want to have done it AFTER the split, to avoid data leakage
X_new = merged_df.drop(columns=['selling_price','currency','year'])
# add a quadratic term for precipitation?
X_new['precip_squared']=X_new['precipitation_sum']**2
y = merged_df['selling_price']
crossval = train_test_split(X_new, 
                            y,
                            test_size=0.3,
                            random_state=42)
Xtrain, Xtest, ytrain, ytest = crossval

# first demonstrate the usage by fitting the full model
# set up both models using scikit-learn
# modelA = LinearRegression()

Xtrain = pd.get_dummies(Xtrain, columns=['prod_veg', 'geo'], drop_first=True)
Xtest = pd.get_dummies(Xtest, columns=['prod_veg', 'geo'], drop_first=True)

Xtrain = Xtrain.astype(float)
Xtest = Xtest.astype(float)

# align columns in case any categories only appear in one split
Xtrain, Xtest = Xtrain.align(Xtest, join='left', axis=1, fill_value=0)

# Scale numeric cols only
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_cols = ['temperature_2m_mean', 'precipitation_sum','precip_squared']
Xtrain[numeric_cols] = scaler.fit_transform(Xtrain[numeric_cols])
Xtest[numeric_cols] = scaler.transform(Xtest[numeric_cols])

b = line_of_best_fit(Xtrain, ytrain)
linreg = linreg_predict(Xtest, ytest, b)
resids = linreg['resids']

print(f'MSE: {linreg['mse']}')
print(f'r2: {linreg['r2']}')
# Out:
# MSE: 25.027308734130877
# r2: 0.4757885430866585

# %% [markdown]
# #### Checking assumptions

# %%
# predicted values versus residuals
plt.scatter(linreg['ypreds'], resids, alpha=0.5)
plt.xlabel("y hat values")
plt.ylabel("residuals")
plt.title("residual plot vs. y hat values")
plt.show()

# %%
plt.scatter(range(len(ytest)), resids, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("index")
plt.ylabel("residuals")
plt.title("residual plot vs. order")
plt.show()

# %% [markdown]
# ## Time series model

# %%
merged_df = merged_df.sort_values(['geo', 'prod_veg', 'year'])
merged_df['price_lag1'] = merged_df.groupby(['geo', 'prod_veg'])['selling_price'].shift(1)
merged_df['price_lag2'] = merged_df.groupby(['geo', 'prod_veg'])['selling_price'].shift(2)
merged_df = merged_df.dropna(subset=['price_lag1','price_lag2'])

# then rebuild X_new with price_lag1 included
X_new_lag = merged_df.drop(columns=['selling_price', 'currency', 'year'])
X_new_lag['precip_squared']=X_new['precipitation_sum']**2
y = merged_df['selling_price']

# %%
crossval = train_test_split(X_new_lag, 
                            y,
                            test_size=0.3,
                            random_state=42)
Xtrainlag, Xtestlag, ytrain, ytest = crossval

# first demonstrate the usage by fitting the full model
# set up both models using scikit-learn
modelAlag = LinearRegression()

Xtrainlag = pd.get_dummies(Xtrainlag, columns=['prod_veg', 'geo'], drop_first=True)
Xtestlag = pd.get_dummies(Xtestlag, columns=['prod_veg', 'geo'], drop_first=True)

# align columns in case any categories only appear in one split
Xtrainlag, Xtestlag = Xtrainlag.align(Xtestlag, join='left', axis=1, fill_value=0)

# Scale numeric cols only
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_cols = ['temperature_2m_mean', 'precipitation_sum','precip_squared','price_lag1','price_lag2']
# numeric_cols = ['temperature_2m_mean','price_lag1']
Xtrainlag[numeric_cols] = scaler.fit_transform(Xtrainlag[numeric_cols])
Xtestlag[numeric_cols] = scaler.transform(Xtestlag[numeric_cols])

# Fit
modelAlag.fit(Xtrainlag, ytrain)

# Predict
predAlag = modelAlag.predict(Xtestlag)

resAlag = predAlag - ytest

MSE_Alag = (resAlag**2).mean()

r2_Alag = 1 - (MSE_Alag)/(ytest.var())

print(f'r2: {r2_Alag}')
print(f'MSE: {MSE_Alag}')
# Out:
# r2: 0.7491224225556194
# MSE: 3.7482307380110313

# %%
print(modelAlag.coef_)
print(modelAlag.intercept_)
# Out:
# [ 0.37147593 -0.82504888  1.82078536  1.22056476  1.17870751  2.66926858
#  -0.42547627 -0.07910352  0.88630979 -1.17084474  0.29332731 -1.70805436
#   3.24657082 -0.35525922  2.8493606   1.38020006  3.01417377 -0.74687685
#   0.25842368 -0.62464055  3.87023599  2.69986057 -0.22217341  0.35413293
#   1.03962526  0.92170022  0.64944742  0.93454035 -1.09212772  1.06459465
#  -0.45725554 -0.46276016  0.32939282]
# 17.970252608426144

# %%
# predicted values versus residuals
plt.scatter(predAlag, resAlag, alpha=0.5)
plt.xlabel("y hat values")
plt.ylabel("residuals")
plt.title("residual plot vs. y hat values")
plt.show()

# %%
plt.scatter(range(len(ytest)), resAlag, alpha=0.5)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("index")
plt.ylabel("residuals")
plt.title("residual plot vs. order")
plt.show()

# %%
results_df = pd.DataFrame({
    'actual': ytest,
    'predicted': predAlag
})

fig = px.scatter(results_df, x='actual', y='predicted',
    title='Actual vs Predicted Selling Price')

fig.add_shape(type='line',
    x0=ytest.min(), y0=ytest.min(),
    x1=ytest.max(), y1=ytest.max(),
    line=dict(color='red', dash='dash'))

fig.show()

# %% [markdown]
# ## Fit on full dataset

# %%
X_full = pd.get_dummies(X_new_lag, columns=['prod_veg', 'geo'], drop_first=True)
X_full = X_full.astype(float)

scaler_full = StandardScaler()
numeric_cols = ['temperature_2m_mean', 'precipitation_sum', 'precip_squared', 'price_lag1', 'price_lag2']
X_full[numeric_cols] = scaler_full.fit_transform(X_full[numeric_cols])

# fit on everything
final_model = LinearRegression()
final_model.fit(X_full, y)
# Out:
# LinearRegression()

# %%
# Predict
predAlag = modelAlag.predict(Xtestlag)

resAlag = predAlag - ytest

MSE_Alag = (resAlag**2).mean()

r2_Alag = 1 - (MSE_Alag)/(ytest.var())

print(f'r2: {r2_Alag}')
print(f'MSE: {MSE_Alag}')

print(modelAlag.coef_)
print(modelAlag.intercept_)
# Out:
# r2: 0.7491224225556194
# MSE: 3.7482307380110313
# [ 0.37147593 -0.82504888  1.82078536  1.22056476  1.17870751  2.66926858
#  -0.42547627 -0.07910352  0.88630979 -1.17084474  0.29332731 -1.70805436
#   3.24657082 -0.35525922  2.8493606   1.38020006  3.01417377 -0.74687685
#   0.25842368 -0.62464055  3.87023599  2.69986057 -0.22217341  0.35413293
#   1.03962526  0.92170022  0.64944742  0.93454035 -1.09212772  1.06459465
#  -0.45725554 -0.46276016  0.32939282]
# 17.970252608426144

# %%
beta_vals = [final_model.intercept_] + list(final_model.coef_)
feature_means = list(scaler_full.mean_)
feature_stds = list(scaler_full.scale_)

print("beta_vals:", json.dumps(beta_vals))
print("feature_means:", json.dumps(feature_means))
print("feature_stds:", json.dumps(feature_stds))
# Out:
# beta_vals: [18.76528131992353, 0.4395023300115466, -0.36885073989100237, 2.2013231632126735, 1.1207381049347107, 0.7893850872270421, 1.1380283076380877, -0.5029495429645382, -0.634217890034992, 0.4531026091993922, -0.7455228115714604, 0.2604294999772836, -0.8312646887379568, 2.312233340578175, 0.23912872320678263, 2.445475529885603, 0.6322941558875317, 1.9072300650448335, 0.7714820957708662, 0.27915407588619584, -0.41015774794396703, 2.9761937178303413, 2.2376129005634344, -0.5137987914096419, -0.11740895031365493, 0.9592454876450357, 0.057426126820612655, -0.029147637632855636, -0.08816101068713166, -1.4931050994892154, 0.46370885814230445, -0.5263104766734047, -0.5781942817571771, 0.13040279857671594]
# feature_means: [12.553323235923022, 735.3423913043476, 590783.3555434782, 21.860760869565215, 30.296086956521737]
# feature_stds: [3.391847370608103, 223.72957581482527, 371975.20699760463, 5.3219948110556805, 6.851753973558719]

# %%
# predicted values versus residuals
plt.scatter(predAlag, resAlag, alpha=0.5)
plt.xlabel("y hat values")
plt.ylabel("residuals")
plt.title("residual plot vs. y hat values")
plt.show()
